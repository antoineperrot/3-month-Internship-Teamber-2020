# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from tqdm import tqdm

import googlemaps
API_key = 'AIzaSyBrpQ4wnAQLv-i7-YLnqxvKVjF9j83pHUo'
gmaps = googlemaps.Client(key=API_key)

# %% [markdown]
# # Objectif : Sur la base de rendez-vous fermes (datés et localisés) on va proposer à l'utilisateur une tournée "optimisée" dans laquelle on essaiera de le faire visiter par la même occasion par des prospects/clients
#
#
# ### 3 modes de sélections sont disponibles :
# - Selection 1 : PROSPECTS dont esperance de concrétisation > 70% + date dernier contact > 1 mois
# - Sélection 2 : les PROSPECTS dont la date de dernier contact est > 3 mois
# - Sélection 3 : les CLIENTS dont la date dernier contact est > 4 mois.
#
#
# ### Raffinage de la sélection par région/département :
# Il est important de ne garder que les adresses réellement intéressantes dans notre sélection d'adresses candidates. Cela pour la raison suivante :
# Admettons que l'on ait 90 adresses. On va alors demander 90² itinéraires à google maps, impliquant des coûts et des temps de réponses supplémentaires.
# Ainsi il vaut mieux ne cibler que les adresses vraiment intéressantes. Si notre tournée a plutôt lieu dans sud-ouest, inutile de garder des adresses dans le nord pas de calais.
# On indiquera donc une sélection de départements et l'on filtrera les adresses grâce à leur code postal.
#
# ### La liste des paramètres du programme :
#
# - DEBUT_JOURNEE : à partir de quelle heure le commercial est-il disponible
# - FIN_JOURNEE : à partir de quelle heure le commercial n'est-il plus disponible
# - DUREE_CLIENTS : combien de temps passe-t-on en général chez un client ?
# - DUREE_PROSPECTS : combien de temps passe-t-on en général chez un prospect ?
# - MARGE_STOP : si l'on a moins de Marge stop heures avant prochain rendez-vous, on ne cherche plus à ajouter de nouveaux arrêts sur le trajet
# - MODE_SELECTION : explication ci-dessus
# - RAYON_SELECTION : rayon des cercles en mètres à tracer le long de la route.

# %%
DEBUT_JOURNEE = datetime.time(8,0)
FIN_JOURNEE = datetime.time(18,30)
DUREE_CLIENTS = datetime.timedelta(hours=2)
DUREE_PROSPECTS = datetime.timedelta(hours=0.5)
MARGE_STOP = datetime.timedelta(hours=.5)
MODE_SELECTION = 3
RAYON_SELECTION = 5000

# %% [markdown]
# ### Import des contacts :
#
# On attend un fichier de type excel/csv/json avec les colonnes :
# - Nom
# - Adresse
# - Code postal
# - Date de dernier contact
# - Type (Client ou Prospect)
# - Espérance concrétisation
# - Latitude
# - Longitude
#
#
# Remarque : dans le fichier suivant, les dates dernier contact, type, espérance concrétisation ont été inventés et sont donc disponibles pour chacun des contacts. Il est fort problable que ces champs ne soient pas connus pour certains contacts, ce qui posera problème au moment de les sélectionner. On pourrait donc choisir de sélectionner ou non tous les contacts dont l'un de ces champs est inconnu. Je vous laisse vous charger de cette question !

# %%
df = pd.read_excel('fichier contact.xlsx')
df.drop('Unnamed: 0',axis=1,inplace=True)
print(len(df))
df.head()
# Out:
# 1327
#                                    Nom  \
# 0                  SARL  ENZO & ROSSO
# 1                    MELIN & ASSOCIES
# 2                         CONSTRUCTYS
# 3                   SACMA Agencements
# 4  Agence d’architecture  PATRIARCHE
#
#                                          Adresse    Type  Département  \
# 0      113 boulevard de Lamasquère - 31600 Muret  Client           31
# 1  Za Chemin De Cormeilles  - 27230  THIBERVILLE  Client           27
# 2  10 Rue Claude-Marie Perroud - 31100  Toulouse  Client           31
# 3       15 rue du Vercors - 42100 Sainte Etienne  Client           42
# 4               12 Rue de Libourne - 75012 Paris  Client           75
#
#     Latitude  Longitude  Espérance concrétisation Dernier contact
# 0  43.468974   1.310368                  0.381346      2020-02-14
# 1  49.141050   0.452514                  0.127340      2020-03-04
# 2  43.576596   1.380879                  0.308407      2020-03-23
# 3  45.414541   4.383612                  0.544425      2020-05-09
# 4  48.832089   2.386602                  0.710477      2020-06-24

# %% [markdown]
# ## 1. Sélection d'adresses candidates :

# %%
if MODE_SELECTION == 1 :
    sel = df.loc[(df["Type"]=='Prospect') &
            (df['Espérance concrétisation'] > .7) & 
            (datetime.datetime.now() - df['Dernier contact'] > datetime.timedelta(days= 30*3))
              ,].reset_index(drop=True)
if MODE_SELECTION == 2 :
    sel = df.loc[(df["Type"]=='Prospect') &
            (df['Espérance concrétisation'] > .7) & 
            (datetime.datetime.now() - df['Dernier contact'] > datetime.timedelta(days= 30*3))
              ,].reset_index(drop=True)
if MODE_SELECTION == 3 :
    sel = df.loc[(datetime.datetime.now() - df['Dernier contact'] > datetime.timedelta(days= 4*30))
              ,].reset_index(drop=True)

#sel = sel.loc[sel['Département'].isin(SECTEUR),].reset_index(drop=True)
sel['Ajouté'] = False
sel['Valide'] = False

print('Mode sélection :',MODE_SELECTION)
print(len(sel),'adresses candidates')
sel.head()
# Out:
# Mode sélection : 3
# 326 adresses candidates
#                                                 Nom  \
# 0                               SARL  ENZO & ROSSO
# 1                                 MELIN & ASSOCIES
# 2                                a/LTA architectes
# 3                                     ATELIERS 234
# 4    VINCI Construction Pole Ouvrages Fonctionnels
#
#                                             Adresse    Type  Département  \
# 0         113 boulevard de Lamasquère - 31600 Muret  Client           31
# 1     Za Chemin De Cormeilles  - 27230  THIBERVILLE  Client           27
# 2         22 avenue Henri Fréville  - 35203  RENNES  Client           35
# 3  234 Rue du Faubourg Saint-Antoine -  75012 Paris  Client           75
# 4   2 rue du Cottage Tolbiac - 94550 CHEVILLY LARUE  Client           94
#
#     Latitude  Longitude  Espérance concrétisation Dernier contact  Ajouté  \
# 0  43.468974   1.310368                  0.381346      2020-02-14   False
# 1  49.141050   0.452514                  0.127340      2020-03-04   False
# 2  48.087676  -1.675329                  0.527944      2020-02-15   False
# 3  48.849302   2.388728                  0.028637      2020-03-07   False
# 4  48.765447   2.357766                  0.313542      2020-03-07   False
#
#    Valide
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %% [markdown]
# ## 2. Import des rendez-vous fermes :

# %%
df_rdv = pd.read_excel('RDV fermes.xlsx')
df_rdv.drop('Unnamed: 0',axis=1, inplace=True)

#Geocoding des rdv fermes si nécessaire :
'''
import googlemaps
API_key = 'AIzaSyBrpQ4wnAQLv-i7-YLnqxvKVjF9j83pHUo'
gmaps = googlemaps.Client(key=API_key)  

geocodes_rdv = []
for adresse in df_rdv['Adresse'].values:
    geocode_rdv = gmaps.geocode(adresse)
    geocodes_rdv.append(geocode_rdv)

lats, lons = [], []
for geo in geocodes_rdv :
    lats.append(geo[0]['geometry']['location']['lat'])
    lons.append(geo[0]['geometry']['location']['lng'])
    
df_rdv['Latitude'] = lats
df_rdv['Longitude'] = lons
'''

df_rdv.head()
# Out:
#                        Nom          Date début            Date fin  \
# 0          Départ de Muret 2020-06-15 08:30:00 2020-06-15 08:30:00
# 1          Foire MARSEILLE 2020-06-15 14:00:00 2020-06-15 19:00:00
# 2               Foire LYON 2020-06-16 14:00:00 2020-06-17 12:00:00
# 3  Expo Brive la gaillarde 2020-06-18 14:00:00 2020-06-18 16:00:00
# 4             Retour Muret 2020-06-19 12:00:00 2020-06-19 12:00:00
#
#                                    Adresse Type   Latitude  Longitude
# 0  113 Boulevard de Lamasquère 31600 Muret  RDV  43.468974   1.310368
# 1                         Marseille Chanot  RDV  43.272705   5.394742
# 2                             Eurexpo Lyon  RDV  45.731008   4.951443
# 3               gare de Brive la Gaillarde  RDV  45.152560   1.528619
# 4  113 Boulevard de Lamasquère 31600 Muret  RDV  43.468974   1.310368

# %% [markdown]
# #### Fonction calculant la distance à vol d'oiseau entre deux points :

# %%
def dist_vol_doiseau(LatA,LonA,LatB,LonB):
    latA = LatA*np.pi/180
    lonA = LonA*np.pi/180
    latB = LatB*np.pi/180
    lonB = LonB*np.pi/180
    RAYON_TERRE = 6_378_000 #en m   car non la terre n'est pas plate
    dist = np.arccos(np.cos(latA)*np.cos(lonA)*np.cos(latB)*np.cos(lonB) + \
    np.cos(latA)*np.sin(lonA)*np.cos(latB)*np.sin(lonB) + \
    np.sin(latA)*np.sin(latB)) * RAYON_TERRE  #
    return int(dist)

# %% [markdown]
# ## 3. Raffinage sélection :
#
# Afin de raffiner notre sélection d'adresses candidates, nous allons ne garder que les adresses se situant à moins de RAYON_CERCLE km des points situés sur la route initiale. La route initiale est l'itinéraire que devrait suivre le commercial s'il ne se rendait qu'à ses rendez-vous fermes.
# Les points situés le long de cet itinéraire correspondent à des instructions GPS (tourner à gauche, prendre bifurcation, etc..).
# On tracera des cercles centrés sur ces points et ne retiendra que les adresses qui tombent à l'intérieur d'au moins un des cercles.
#
# ### 3.1. Obtentions de points le long de la route :

# %%
adresses_rdv = list(df_rdv['Adresse'].values)
resultats = []
for i in range(len(adresses_rdv)-1):
    resultats.append(gmaps.directions(origin = adresses_rdv[i],destination = adresses_rdv[i+1]))

lats_circles = []
lons_circles = []
for res in resultats :
    for i in range(len(res[0]['legs'][0]['steps'])):
        lats_circles.append(res[0]['legs'][0]['steps'][i]['start_location']["lat"])
        lons_circles.append(res[0]['legs'][0]['steps'][i]['start_location']["lng"])

# %% [markdown]
# ### 3.2. Dessin des cercles :

# %%
import gmplot
API_key = 'AIzaSyBrpQ4wnAQLv-i7-YLnqxvKVjF9j83pHUo'

gmap = gmplot.GoogleMapPlotter((np.max(data['Latitude']) + np.min(data['Latitude']))/2,
                               (np.max(data['Longitude']) + np.min(data['Longitude']))/2
                               ,8.5,apikey=API_key)

for i in range(len(lats)):
    gmap.circle(lats_circles[i],lons_circles[i],RAYON_SELECTION)
gmap.draw("along.html")

# %%
lats_circles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e8d47dd53501> in <module>
# ----> 1 lats_circles
#
# NameError: name 'lats_circles' is not defined

# %% [markdown]
# ### 3.3. Raffinage des adresses :
#
# Remarque : on ne garde donc que les adresses à l'intérieur des cercles, mais on retient aussi la distance minimale de chaque adresse par rapport au centre du cercle. Ainsi, s'il reste encore trop d'adresses, on peut choisir de ne retenir que celles qui sont les plus proches des centres des cercles.

# %%
valides = []
dist_mins = []
for index,row in sel.iterrows():
    lat1,lon1 = sel.loc[index,['Latitude','Longitude']].values
    valide = False
    dist_min = np.inf
    for i in range(len(lons_circles)):
        dist = dist_vol_doiseau(lat1,lon1,lats_circles[i],lons_circles[i])
        if dist < dist_min:
            dist_min = dist
        if dist < RAYON_SELECTION:
            valide = True
    if valide:
        valides.append(index)
    dist_mins.append(dist_min)

sel['Distance min cercle'] = dist_mins
sel2 = pd.DataFrame.copy(sel.loc[valides]).reset_index(drop=True)
print('Avant raffinage :',len(sel))
print('Après raffinage :',len(sel2))
print('pour des rayons de',RAYON_SELECTION,'m.')
sel_avoid = sel.drop(valides,axis=0)
# Out:
# Avant raffinage : 326
# Après raffinage : 84
# pour des rayons de 5000 m.

# %% [markdown]
# ### 3.4. Affichage des adresses retenues :

# %%
import gmplot
API_key = 'AIzaSyBrpQ4wnAQLv-i7-YLnqxvKVjF9j83pHUo'

gmap = gmplot.GoogleMapPlotter((np.max(sel2['Latitude']) + np.min(sel2['Latitude']))/2,
                               (np.max(sel2['Longitude']) + np.min(sel2['Longitude']))/2
                               ,8.5,apikey=API_key)
for i in range(len(lats_circles)):
    gmap.circle(lats_circles[i],lons_circles[i],RAYON_SELECTION,alpha=.1)

gmap.scatter(sel_avoid['Latitude'],sel_avoid['Longitude'],marker=True,
            size=800,c='k',alpha=.2)
gmap.scatter(sel2['Latitude'],sel2['Longitude'],marker=True,
            size=800,c='g',alpha = 1)

for i in range(len(df_rdv)-1):
    origin = tuple([df_rdv.loc[i,'Latitude'],df_rdv.loc[i,'Longitude']])
    destination = tuple([df_rdv.loc[i+1,'Latitude'],df_rdv.loc[i+1,'Longitude']])
    
    gmap.directions(origin=origin,
                   destination=destination,marker=False)
        
gmap.draw("along.html")

# %% [markdown]
# On met toutes les adresses (celles des rdv fermes + lieux potentiels) dans un même data frame, dont on va calculer la Distance Matrix

# %%
data = pd.concat([df_rdv[['Nom',"Adresse",'Type','Latitude','Longitude']],
                         sel2[['Nom','Adresse','Type','Latitude','Longitude']]]).reset_index(drop=True)

# %% [markdown]
# ## 4. Google Maps API :
#
#
# ### 4.1. Calcul des Distance Matrix et Duration Matrix using google maps developper API :
# On calcule les durées/distances de toutes les paires origine/destination possible.

# %%
print(len(data))
resultats = []
for i in tqdm(range(len(data))):
    res = gmaps.distance_matrix(origins = [data.loc[i,'Adresse']],
                     destinations = data['Adresse'],
                      mode="driving")
    resultats.append(res)
# Out:
#   0%|                                                   | 0/89 [00:00<?, ?it/s]
# 89
# 100%|██████████████████████████████████████████| 89/89 [00:22<00:00,  4.03it/s]

# %% [markdown]
# Si une reqûete a provoqué une erreur status != 'OK' alors on assigne un trajet de distance/durée infinie, sinon tout va bien.
#
# ### 4.2. Remplissage et affichage des distance/duration matrix :

# %%
DuM = np.zeros((len(data),len(data)))   #Duration Matrix
DiM = np.zeros((len(data),len(data)))   #Distance Matrix

for i in range(len(resultats)):
    res = resultats[i]
    for j in range(len(res['rows'][0]['elements'])):
        if res['rows'][0]['elements'][j]["status"] == 'OK':           
            DuM[i,j] = res['rows'][0]['elements'][j]['duration']['value'] / 60  #en minutes
            DiM[i,j] = res['rows'][0]['elements'][j]['distance']['value'] / 1000 #en km
        else :
            DuM[i,j] = np.inf
            DiM[i,j] = np.inf

DuM = np.round(DuM).astype(int)
DiM = np.round(DiM).astype(int)

plt.figure(figsize=(14,7))
ax1 = plt.subplot(121,title= 'Distance Matrix')
ax2 = plt.subplot(122,title= 'Duration Matrix')
ax1.matshow(DiM)
ax2.matshow(DuM);

# %% [markdown]
# ### (skip) Sauvegarde des données pour pas refaire des demandes API à chaque fois :

# %%
df_rdv.to_csv(f'df_rdv.csv',sep=',')
sel.to_csv(f'sel.csv',sep=',')
data.to_csv(f'data.csv',sep=',')
np.save(f"train_distance_matrix.npy", DiM)
np.save(f"train_duration_matrix.npy", DuM)

# %% [markdown]
# ### (skip) Chargement des données pour pas refaire des demandes API à chaque fois :

# %%
#Pour charger ultérieurement :
import datetime
data = pd.read_csv('data.csv',sep=',',encoding='utf-8')
df_rdv = pd.read_csv('df_rdv.csv',sep=',',encoding='utf-8')
sel = pd.read_csv('sel.csv',sep=',',encoding='utf-8')
DiM = np.load('train_distance_matrix.npy')
DuM = np.load('train_duration_matrix.npy')

df_rdv['Date début'] = pd.to_datetime(df_rdv['Date début'])
df_rdv['Date fin'] = pd.to_datetime(df_rdv['Date fin'])

data.drop('Unnamed: 0',axis=1,inplace=True)
df_rdv.drop('Unnamed: 0',axis=1,inplace=True)
sel.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Notre itinéraire initial est  0 -> 1 -> 2 -> 3 -> 4 (nos rendez-vous fermes). L'idée va être d'ajouter des points sur la route tant que l'on en a le temps.
#
# #### Fonction calculant le temps disponible entre deux rdv fermes compte tenu des horaires de travail du commercial :

# %%
def temps_dispo(row, debut_journee = DEBUT_JOURNEE, fin_journee = FIN_JOURNEE):
    current_day = row['Date fin rdv Origine'].date()
    if current_day  == row['Date début rdv Destination'].date():
        t_dispo = row['Date début rdv Destination'] - row['Date fin rdv Origine']
    else :
        a = pd.to_datetime(str(current_day) + ' '+ str(fin_journee))
        t_dispo = a - row['Date fin rdv Origine'] if a - row['Date fin rdv Origine'] >= datetime.timedelta(0) else datetime.timedelta(0)
        current_day += datetime.timedelta(days=1)
        while current_day != row['Date début rdv Destination'].date() :
            t_dispo += pd.to_datetime(fin_journee) - pd.to_datetime(debut_journee)
            current_day += datetime.timedelta(days=1)
        b = pd.to_datetime(str(current_day) + ' '+ str(debut_journee))
        t_dispo += row['Date début rdv Destination'] - b if row['Date début rdv Destination'] - b > datetime.timedelta(0) else datetime.timedelta(0)
    return t_dispo

# %% [markdown]
# ## 5. Coeur du programme
#
#
# ### 5.1. Préparation d'un dataframe "InterRDV"

# %%
InterRDV = pd.DataFrame()
InterRDV['Origine'] = df_rdv.loc[df_rdv.index[:-1],'Nom'].values
InterRDV['Origine Id'] = df_rdv.index[:-1]
InterRDV['Destination'] = df_rdv.loc[df_rdv.index[1:],'Nom'].values
InterRDV['Destination Id'] = df_rdv.index[1:]

InterRDV['Date fin rdv Origine'] = df_rdv.loc[df_rdv.index[:-1],'Date fin'].values
InterRDV['Date début rdv Destination'] = df_rdv.loc[df_rdv.index[1:],'Date début'].values

for index, row in InterRDV.iterrows():
    InterRDV.loc[index,'Temps trajet initial'] = DuM[row['Origine Id'],row['Destination Id']]
    InterRDV.loc[index,'Distance trajet initial (km)'] = int(DiM[row['Origine Id'],row['Destination Id']])
    InterRDV.loc[index,'Temps dispo interRDV'] = temps_dispo(row)

InterRDV['Temps trajet initial'] = pd.to_timedelta(InterRDV['Temps trajet initial'],unit='m')
InterRDV['Temps trajet supplémentaire'] = pd.to_timedelta(0,unit='h')
InterRDV['km ajoutés'] = 0
InterRDV['Visites'] =''
InterRDV['Prospects visités'] = 0
InterRDV['Clients visités'] = 0
InterRDV['Temps restant'] = InterRDV['Temps dispo interRDV'] \
                        - InterRDV['Temps trajet initial']\
                        - InterRDV['Temps trajet supplémentaire']\
                        - DUREE_CLIENTS * InterRDV['Clients visités'] \
                        - DUREE_PROSPECTS * InterRDV['Prospects visités']    
InterRDV
# Out:
#                    Origine  Origine Id              Destination  \
# 0          Départ de Muret           0          Foire MARSEILLE
# 1          Foire MARSEILLE           1               Foire LYON
# 2               Foire LYON           2  Expo Brive la gaillarde
# 3  Expo Brive la gaillarde           3             Retour Muret
#
#    Destination Id Date fin rdv Origine Date début rdv Destination  \
# 0               1  2020-06-15 08:30:00        2020-06-15 14:00:00
# 1               2  2020-06-15 19:00:00        2020-06-16 14:00:00
# 2               3  2020-06-17 12:00:00        2020-06-18 14:00:00
# 3               4  2020-06-18 16:00:00        2020-06-19 12:00:00
#
#   Temps trajet initial  Distance trajet initial (km) Temps dispo interRDV  \
# 0             04:09:00                         423.0             05:30:00
# 1             03:10:00                         322.0             06:00:00
# 2             03:46:00                         380.0             12:30:00
# 3             02:14:00                         219.0             06:30:00
#
#   Temps trajet supplémentaire  km ajoutés Visites  Prospects visités  \
# 0                      0 days           0                          0
# 1                      0 days           0                          0
# 2                      0 days           0                          0
# 3                      0 days           0                          0
#
#    Clients visités Temps restant
# 0                0      01:21:00
# 1                0      02:50:00
# 2                0      08:44:00
# 3                0      04:16:00

# %% [markdown]
# ### 5.2. Optimisation de la tournée :
#
# Pour chaque paires de rendez-vous fermes :
# Tant que cela est possible. C'est à dire :
# - tant qu'il reste des adresses candidates
# - tant qu'il nous reste au moins MARGE_STOP minutes disponibles entre les deux rdv
# - tant qu'il existe au moins une adresse à laquelle on a le temps de s'arrêter
#
# Alors on cherche l'adresse candidate telle que le temps de trajet supplémentaire est minimal, sans faire la distinction clients/prospects et on l'ajoute.

# %%
lieux_potentiels_restant = np.array(sel2.loc[sel["Ajouté"]==False,].index) # + len(df_rdv)
categorie_lieux_potentiels_restant = np.array((sel2['Type'] =='Prospect' )* 1)

trajets = []
lieux_ajoutes = []
for index, row in InterRDV.iterrows():
    arg_org  = InterRDV.loc[index,"Origine Id"]
    arg_dest = InterRDV.loc[index,"Destination Id"]
    trajet = [arg_org, arg_dest]   #dans la Duration matrix
    temps_restant = InterRDV.loc[index,'Temps restant']
    stop  = temps_restant < MARGE_STOP or len(lieux_potentiels_restant) == 0
    while not stop :
        devmin = np.inf
        argmin = None
        etape = None
        t_surplacemin = None
        imin = 0
        existe_candidat = False
        for i in range(len(lieux_potentiels_restant)):
            arg = lieux_potentiels_restant[i] + len(df_rdv)
            for t in range(len(trajet)-1) :
                dev = DuM[trajet[t],arg] + DuM[arg,trajet[t+1]] - DuM[trajet[t],trajet[t+1]]
                t_surplace = DUREE_PROSPECTS if categorie_lieux_potentiels_restant[i] else DUREE_CLIENTS
                possible = InterRDV.loc[index,'Temps restant'] >= datetime.timedelta(hours=dev / 60) +  t_surplace
                if possible and dev < devmin :
                    existe_candidat = True
                    argmin = lieux_potentiels_restant[i] + len(df_rdv)    #argmin dans la Duration Matrix
                    imin = i
                    etape = t
                    devmin = dev
                    km_sup = DiM[trajet[t],arg] + DiM[arg,trajet[t+1]] - DiM[trajet[t],trajet[t+1]]
                    categorie = 'Client' if categorie_lieux_potentiels_restant[i] == 0 else 'Prospect'
                    t_surplacemin = t_surplace
        if existe_candidat :
            lieux_ajoutes.append(imin)
            sel2.loc[imin,'Ajouté'] = True
            trajet.insert(etape+1,argmin) 
            InterRDV.loc[index,'km ajoutés'] += km_sup
            InterRDV.loc[index,'Temps trajet supplémentaire'] += datetime.timedelta(hours=devmin / 60)
            InterRDV.loc[index,categorie+'s visités'] += 1
            InterRDV.loc[index,'Temps restant'] -= datetime.timedelta(hours=devmin / 60) + t_surplacemin
            lieux_potentiels_restant = np.delete(lieux_potentiels_restant,imin)
            categorie_lieux_potentiels_restant = np.delete(categorie_lieux_potentiels_restant,imin)
            #temps_restant = row['Temps restant']
        stop  = InterRDV.loc[index,'Temps restant'] < MARGE_STOP or len(lieux_potentiels_restant) == 0 or not existe_candidat
    if index == 0:
        trajets = trajet
    if index > 0:
        trajets = trajets + trajet[1:]
    InterRDV.loc[index,'Visites'] = str(trajet[1:-1])[1:-1]
    
InterRDV['Temps prospects'] = InterRDV['Prospects visités'] * DUREE_PROSPECTS
InterRDV['Temps clients'] = InterRDV['Clients visités'] * DUREE_CLIENTS
InterRDV
# Out:
#                    Origine  Origine Id              Destination  \
# 0          Départ de Muret           0          Foire MARSEILLE
# 1          Foire MARSEILLE           1               Foire LYON
# 2               Foire LYON           2  Expo Brive la gaillarde
# 3  Expo Brive la gaillarde           3             Retour Muret
#
#    Destination Id Date fin rdv Origine Date début rdv Destination  \
# 0               1  2020-06-15 08:30:00        2020-06-15 14:00:00
# 1               2  2020-06-15 19:00:00        2020-06-16 14:00:00
# 2               3  2020-06-17 12:00:00        2020-06-18 14:00:00
# 3               4  2020-06-18 16:00:00        2020-06-19 12:00:00
#
#   Temps trajet initial  Distance trajet initial (km) Temps dispo interRDV  \
# 0             04:09:00                         423.0             05:30:00
# 1             03:10:00                         322.0             06:00:00
# 2             03:46:00                         380.0             12:30:00
# 3             02:14:00                         219.0             06:30:00
#
#   Temps trajet supplémentaire  km ajoutés                     Visites  \
# 0                    00:07:00           2                      57, 58
# 1                    00:14:00           4                      83, 12
# 2                    00:38:00          10  48, 85, 43, 36, 49, 47, 66
# 3                    00:00:00           0                       44, 5
#
#    Prospects visités  Clients visités Temps restant Temps prospects  \
# 0                  2                0      00:14:00        01:00:00
# 1                  1                1      00:06:00        00:30:00
# 2                  4                3      00:06:00        02:00:00
# 3                  0                2      00:16:00        00:00:00
#
#   Temps clients
# 0      00:00:00
# 1      02:00:00
# 2      06:00:00
# 3      04:00:00

# %%
InterRDV[['Origine','Destination','Date fin rdv Origine','Date début rdv Destination',
          'Temps dispo interRDV','Temps trajet initial','Temps trajet supplémentaire',
          'Distance trajet initial (km)','km ajoutés',
          'Prospects visités','Clients visités',
         'Temps prospects','Temps clients','Temps restant']]
# Out:
#                    Origine              Destination Date fin rdv Origine  \
# 0          Départ de Muret          Foire MARSEILLE  2020-06-15 08:30:00
# 1          Foire MARSEILLE               Foire LYON  2020-06-15 19:00:00
# 2               Foire LYON  Expo Brive la gaillarde  2020-06-17 12:00:00
# 3  Expo Brive la gaillarde             Retour Muret  2020-06-18 16:00:00
#
#   Date début rdv Destination Temps dispo interRDV Temps trajet initial  \
# 0        2020-06-15 14:00:00             05:30:00             04:09:00
# 1        2020-06-16 14:00:00             06:00:00             03:10:00
# 2        2020-06-18 14:00:00             12:30:00             03:46:00
# 3        2020-06-19 12:00:00             06:30:00             02:14:00
#
#   Temps trajet supplémentaire  Distance trajet initial (km)  km ajoutés  \
# 0                    00:07:00                         423.0           2
# 1                    00:14:00                         322.0           4
# 2                    00:38:00                         380.0          10
# 3                    00:00:00                         219.0           0
#
#    Prospects visités  Clients visités Temps prospects Temps clients  \
# 0                  2                0        01:00:00      00:00:00
# 1                  1                1        00:30:00      02:00:00
# 2                  4                3        02:00:00      06:00:00
# 3                  0                2        00:00:00      04:00:00
#
#   Temps restant
# 0      00:14:00
# 1      00:06:00
# 2      00:06:00
# 3      00:16:00

# %% [markdown]
# ### 5.3. Calcul des horaires de passages pour la tournée :

# %%
tournee = data.loc[trajets].reset_index(drop=True)
tournee['Id DiM'] = trajets

for index,row in tournee.iterrows():
    if row['Type'] =='RDV':
        tournee.loc[index,'Date début'] = df_rdv.loc[df_rdv['Nom']==row['Nom'],'Date début'].values
        tournee.loc[index,'Date fin'] = df_rdv.loc[df_rdv['Nom']==row['Nom'],'Date fin'].values
    else :
        duree_trajet = (np.timedelta64(DuM[tournee.loc[index-1,'Id DiM'],tournee.loc[index,'Id DiM']],'m'))
        if tournee.loc[index -1,'Date fin'].time() > FIN_JOURNEE :
            dt = tournee.loc[index -1,'Date fin'] + datetime.timedelta(days=1)
            dt = pd.to_datetime(str(dt)[:11] + str(DEBUT_JOURNEE))
            tournee.loc[index,'Date début'] = dt + duree_trajet
            t_surplace = DUREE_CLIENTS if row['Type'] =='Client' else DUREE_PROSPECTS
            tournee.loc[index,'Date fin'] = tournee.loc[index,'Date début'] + t_surplace
        elif (tournee.loc[index -1,'Date fin'] + duree_trajet).time() > FIN_JOURNEE :
            dt = tournee.loc[index -1,'Date fin']
            fj = pd.to_datetime(str(dt)[:11] + str(FIN_JOURNEE))
            duree_trajet_restant = duree_trajet
            duree_trajet_restant -= fj - dt
            dt += datetime.timedelta(days=1)
            dt = pd.to_datetime(str(dt)[:11] + str(DEBUT_JOURNEE))
            tournee.loc[index,'Date début'] = dt + duree_trajet_restant
            t_surplace = DUREE_CLIENTS if row['Type'] =='Client' else DUREE_PROSPECTS
            tournee.loc[index,'Date fin'] = tournee.loc[index,'Date début'] + t_surplace
            
        else : 
            tournee.loc[index,'Date début'] = tournee.loc[index -1,'Date fin'] + duree_trajet
            t_surplace = DUREE_CLIENTS if row['Type'] =='Client' else DUREE_PROSPECTS
            tournee.loc[index,'Date fin'] = tournee.loc[index,'Date début'] + t_surplace
            
tournee
# Out:
#                                                   Nom  \
# 0                                     Départ de Muret
# 1                           Bureau d'étude  AXIOLIS
# 2   Agence d’architecture  SARL SOCIETE D'ARCHITEC...
# 3                                     Foire MARSEILLE
# 4                             SAS  GARCIA INGENIERIE
# 5                                      Société  TPFI
# 6                                          Foire LYON
# 7                              Bureau d'étude  ELEYS
# 8                       Agence d’architecture  AAMCO
# 9                                   M. Remy GAILLARD
# 10       Agence d’architecture  H.T.V.S Architecture
# 11                            Bureau d'étude  KORELL
# 12                                  M. Anthony SIMON
# 13                 Agence d’architecture  ARCHIGROUP
# 14                            Expo Brive la gaillarde
# 15                                 M. Stéphane ZANON
# 16                                SARL  ENZO & ROSSO
# 17                                       Retour Muret
#
#                                               Adresse      Type   Latitude  \
# 0             113 Boulevard de Lamasquère 31600 Muret       RDV  43.468974
# 1            210 avenue de Toulon - 13010  Marseille   Prospect  43.284445
# 2               30 Rue Louis Rège - 13008  Marseille   Prospect  43.281272
# 3                                    Marseille Chanot       RDV  43.272705
# 4   164 Chemin Saint Jean du désert - 13005 Marseille  Prospect  43.294051
# 5   Immeuble Le Balthazar  2 quai d’Arenc - 13002 ...    Client  43.312706
# 6                                        Eurexpo Lyon       RDV  45.731008
# 7          51 Rue Emile Decorps - 69100  Villeurbanne  Prospect  45.756325
# 8                20 Rue Octavie - 69100  Villeurbanne  Prospect  45.780496
# 9                  25 rue Joannes Carret - 69009 Lyon    Client  45.792933
# 10                      2 rue de la Gare - 69009 Lyon    Client  45.779188
# 11  17 Rue Georges Perret  - 69160  Tassin-la-Demi...  Prospect  45.763182
# 12  Mini Parc Bat 3 3 chemin du Jubin - 69570 Dard...    Client  45.813897
# 13          411 allée des noisetiers - 69760 Limonest  Prospect  45.815267
# 14                         gare de Brive la Gaillarde       RDV  45.152560
# 15                 113 BD DE LAMASQUERE - 31600 MURET    Client  43.468974
# 16          113 boulevard de Lamasquère - 31600 Muret    Client  43.468974
# 17            113 Boulevard de Lamasquère 31600 Muret       RDV  43.468974
#
#     Longitude  Id DiM          Date début            Date fin
# 0    1.310368       0 2020-06-15 08:30:00 2020-06-15 08:30:00
# 1    5.395274      57 2020-06-15 12:35:00 2020-06-15 13:05:00
# 2    5.391288      58 2020-06-15 13:10:00 2020-06-15 13:40:00
# 3    5.394742       1 2020-06-15 14:00:00 2020-06-15 19:00:00
# 4    5.412484      83 2020-06-16 08:10:00 2020-06-16 08:40:00
# 5    5.366855      12 2020-06-16 08:54:00 2020-06-16 10:54:00
# 6    4.951443       2 2020-06-16 14:00:00 2020-06-17 12:00:00
# 7    4.899909      48 2020-06-17 12:14:00 2020-06-17 12:44:00
# 8    4.887820      85 2020-06-17 12:52:00 2020-06-17 13:22:00
# 9    4.819577      43 2020-06-17 13:32:00 2020-06-17 15:32:00
# 10   4.801439      36 2020-06-17 15:39:00 2020-06-17 17:39:00
# 11   4.780106      49 2020-06-17 17:46:00 2020-06-17 18:16:00
# 12   4.759383      47 2020-06-17 18:27:00 2020-06-17 20:27:00
# 13   4.773472      66 2020-06-18 08:05:00 2020-06-18 08:35:00
# 14   1.528619       3 2020-06-18 14:00:00 2020-06-18 16:00:00
# 15   1.310368      44 2020-06-18 18:14:00 2020-06-18 20:14:00
# 16   1.310368       5 2020-06-19 08:00:00 2020-06-19 10:00:00
# 17   1.310368       4 2020-06-19 12:00:00 2020-06-19 12:00:00

# %% [markdown]
# ## 6. Affichage de la tournée :

# %%
import gmplot
API_key = 'AIzaSyBrpQ4wnAQLv-i7-YLnqxvKVjF9j83pHUo'

gmap = gmplot.GoogleMapPlotter((np.max(data['Latitude']) + np.min(data['Latitude']))/2,
                               (np.max(data['Longitude']) + np.min(data['Longitude']))/2
                               ,8.5,apikey=API_key)

##En bleu clair, les adresses des clients :
gmap.scatter(data.loc[data['Type']=='Client','Latitude'].values,
             data.loc[data['Type']=='Client','Longitude'].values,
           '#3399FF', edge_width = 8,marker=False,
            symbol='+')

##En bleu foncé, les adresses des prospects :
gmap.scatter(data.loc[data['Type']=='Prospect','Latitude'].values,
             data.loc[data['Type']=='Prospect','Longitude'].values, 
           '#0000CC', edge_width = 8,marker=False,
            symbol='+')

#En rouge, les adresses des rendez-vous fermes :
#gmap.scatter(lats_rdv, longs_rdv,  
#           'r', edge_width =5,
#             label=['1dwfgwxvc','2xvSVDwvx','wfbwdfhbDF3','4sfgsdf','5cqsdcWD'])

i = 0
done = False

origin = None
destination = None
while not done :
    way_points = []
    current_row = tournee.loc[i,]
    origin = tuple([current_row['Latitude'],current_row['Longitude']])
    i += 1
    current_row = tournee.loc[i,]
    while current_row['Type'] != 'RDV':
        way_points.append( tuple([current_row['Latitude'],current_row['Longitude']]) )
        i += 1
        current_row = tournee.loc[i,]
    destination = tuple([current_row['Latitude'],current_row['Longitude']])
    
    if len(way_points) == 0 :
        gmap.directions(origin=origin,
                   destination=destination)
    else :
        gmap.directions(origin=origin,
                   destination=destination,
                       waypoints=way_points)

        
    done = i == len(tournee) - 1 

gmap.draw("lol20.html")
